# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananthzeke/Deep-Learning/blob/main/Notebooks-Tensorflow/Deep_Feed_forward_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00602/DryBeanDataset.zip
# Out:
# --2022-06-12 09:31:51--  https://archive.ics.uci.edu/ml/machine-learning-databases/00602/DryBeanDataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4738776 (4.5M) [application/x-httpd-php]
# Saving to: ‘DryBeanDataset.zip’
#
# DryBeanDataset.zip  100%[===================>]   4.52M  11.1MB/s    in 0.4s
#
# 2022-06-12 09:31:52 (11.1 MB/s) - ‘DryBeanDataset.zip’ saved [4738776/4738776]

# %%
# !unzip DryBeanDataset.zip
# Out:
# Archive:  DryBeanDataset.zip
#    creating: DryBeanDataset/
#   inflating: DryBeanDataset/Dry_Bean_Dataset.arff
#   inflating: DryBeanDataset/Dry_Bean_Dataset.txt
#   inflating: DryBeanDataset/Dry_Bean_Dataset.xlsx

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/DryBeanDataset/Dry_Bean_Dataset.xlsx')

# %%
df.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER
# 3     0.928329      0.007017      0.003215      0.861794      0.994199  SEKER
# 4     0.970516      0.006697      0.003665      0.941900      0.999166  SEKER

# %%
df['Class'].unique()
# Out:
# array(['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON'],
#       dtype=object)

# %%
df=df.sample(frac=1)

# %%
import numpy as np
import tensorflow as tf

# %%
train,test,val=np.split(df,[int(0.8*len(df)), int(0.9*len(df))])

# %%
labels,indices = np.unique(df["Class"],return_inverse=True)

# %%
indices
# Out:
# array([3, 3, 0, ..., 6, 1, 6])

# %%
def df_to_dataset(dataframe, batch_size=32):
  df = dataframe.copy()
  labels,indices = np.unique(df["Class"],return_inverse=True) 
  df = {key: value.values[:,tf.newaxis] for key, value in dataframe.items()}
  df.pop('Class')
  ds = tf.data.Dataset.from_tensor_slices((dict(df), tf.one_hot(indices,7)))
  ds = ds.batch(batch_size)
  ds = ds.prefetch(batch_size)
  return ds

# %%
batch_size = 64
train_ds = df_to_dataset(train, batch_size=batch_size)
val_ds = df_to_dataset(val, batch_size=batch_size)
test_ds = df_to_dataset(test, batch_size=batch_size)

# %%
def get_normalization_layer(name, dataset):
  normalizer = tf.keras.layers.Normalization(axis=None)
  feature_ds = dataset.map(lambda x, y: x[name])
  normalizer.adapt(feature_ds)
  return normalizer

# %%
numerical_cols = df.drop('Class',axis=1).columns
numerical_cols
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4'],
#       dtype='object')

# %%
all_inputs =[]
encoded_features=[]

# %%
for header in numerical_cols:
  numeric_col = tf.keras.Input(shape=(1,), name=header)
  normalization_layer = get_normalization_layer(header, train_ds)
  encoded_numeric_col = normalization_layer(numeric_col)
  all_inputs.append(numeric_col)
  encoded_features.append(encoded_numeric_col)

# %%
x = tf.keras.layers.concatenate(encoded_features)
x = tf.keras.layers.Dense(64, activation="relu")(x)
x = tf.keras.layers.Dense(32, activation="relu")(x)
x = tf.keras.layers.Dense(16, activation="relu")(x)
x = tf.keras.layers.Dense(8, activation="relu")(x)
outputs = tf.keras.layers.Dense(7, activation="softmax")(x)
model = tf.keras.Model(all_inputs,outputs)
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"]
)

# %%
tf.keras.utils.plot_model(model)

# %%
history = model.fit(train_ds,validation_data=val_ds,epochs=100,callbacks=tf.keras.callbacks.EarlyStopping(patience=5))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 171/171 [==============================] - 8s 14ms/step - loss: 1.1956 - accuracy: 0.5427 - val_loss: 0.5451 - val_accuracy: 0.8722
# Epoch 2/100
# 171/171 [==============================] - 2s 9ms/step - loss: 0.3023 - accuracy: 0.9112 - val_loss: 0.2524 - val_accuracy: 0.9097
# Epoch 3/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.2186 - accuracy: 0.9210 - val_loss: 0.2352 - val_accuracy: 0.9134
# Epoch 4/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.2060 - accuracy: 0.9237 - val_loss: 0.2256 - val_accuracy: 0.9163
# Epoch 5/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1995 - accuracy: 0.9266 - val_loss: 0.2188 - val_accuracy: 0.9207
# Epoch 6/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1953 - accuracy: 0.9284 - val_loss: 0.2155 - val_accuracy: 0.9200
# Epoch 7/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1923 - accuracy: 0.9296 - val_loss: 0.2120 - val_accuracy: 0.9200
# Epoch 8/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1898 - accuracy: 0.9308 - val_loss: 0.2097 - val_accuracy: 0.9214
# Epoch 9/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1880 - accuracy: 0.9309 - val_loss: 0.2076 - val_accuracy: 0.9200
# Epoch 10/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1863 - accuracy: 0.9316 - val_loss: 0.2071 - val_accuracy: 0.9192
# Epoch 11/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1850 - accuracy: 0.9323 - val_loss: 0.2056 - val_accuracy: 0.9207
# Epoch 12/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1839 - accuracy: 0.9321 - val_loss: 0.2050 - val_accuracy: 0.9207
# Epoch 13/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1828 - accuracy: 0.9326 - val_loss: 0.2044 - val_accuracy: 0.9192
# Epoch 14/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1816 - accuracy: 0.9331 - val_loss: 0.2037 - val_accuracy: 0.9200
# Epoch 15/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1807 - accuracy: 0.9337 - val_loss: 0.2039 - val_accuracy: 0.9200
# Epoch 16/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1797 - accuracy: 0.9339 - val_loss: 0.2041 - val_accuracy: 0.9207
# Epoch 17/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1789 - accuracy: 0.9342 - val_loss: 0.2034 - val_accuracy: 0.9214
# Epoch 18/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1781 - accuracy: 0.9339 - val_loss: 0.2036 - val_accuracy: 0.9214
# Epoch 19/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1774 - accuracy: 0.9341 - val_loss: 0.2036 - val_accuracy: 0.9207
# Epoch 20/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1766 - accuracy: 0.9336 - val_loss: 0.2033 - val_accuracy: 0.9229
# Epoch 21/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1759 - accuracy: 0.9340 - val_loss: 0.2036 - val_accuracy: 0.9214
# Epoch 22/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1753 - accuracy: 0.9342 - val_loss: 0.2028 - val_accuracy: 0.9229
# Epoch 23/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1746 - accuracy: 0.9349 - val_loss: 0.2030 - val_accuracy: 0.9236
# Epoch 24/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1739 - accuracy: 0.9344 - val_loss: 0.2026 - val_accuracy: 0.9236
# Epoch 25/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1734 - accuracy: 0.9344 - val_loss: 0.2021 - val_accuracy: 0.9236
# Epoch 26/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1727 - accuracy: 0.9351 - val_loss: 0.2024 - val_accuracy: 0.9244
# Epoch 27/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1720 - accuracy: 0.9355 - val_loss: 0.2018 - val_accuracy: 0.9251
# Epoch 28/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1713 - accuracy: 0.9360 - val_loss: 0.2019 - val_accuracy: 0.9244
# Epoch 29/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1708 - accuracy: 0.9358 - val_loss: 0.2018 - val_accuracy: 0.9244
# Epoch 30/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1701 - accuracy: 0.9360 - val_loss: 0.2018 - val_accuracy: 0.9258
# Epoch 31/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1697 - accuracy: 0.9359 - val_loss: 0.2013 - val_accuracy: 0.9236
# Epoch 32/100
# 171/171 [==============================] - 1s 9ms/step - loss: 0.1692 - accuracy: 0.9364 - val_loss: 0.2012 - val_accuracy: 0.9236
# Epoch 33/100
# 171/171 [==============================] - 1s 6ms/step - loss: 0.1687 - accuracy: 0.9371 - val_loss: 0.2013 - val_accuracy: 0.9251
# Epoch 34/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1681 - accuracy: 0.9368 - val_loss: 0.2017 - val_accuracy: 0.9229
# Epoch 35/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1677 - accuracy: 0.9374 - val_loss: 0.2018 - val_accuracy: 0.9244
# Epoch 36/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1672 - accuracy: 0.9375 - val_loss: 0.2017 - val_accuracy: 0.9251
# Epoch 37/100
# 171/171 [==============================] - 1s 5ms/step - loss: 0.1667 - accuracy: 0.9377 - val_loss: 0.2018 - val_accuracy: 0.9244

# %%
history = history.history

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.title("Accuracy")
plt.plot(history["accuracy"],label="train acc")
plt.plot(history["val_accuracy"],label="val acc")
plt.legend()

plt.subplot(122)
plt.title("Loss")
plt.plot(history["loss"],label="train loss")
plt.plot(history["val_loss"],label="val loss")
plt.legend()

plt.show()

# %%
loss ,accuracy = model.evaluate(test_ds)
# Out:
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2332 - accuracy: 0.9295

# %%
print("test loss :",loss)
print("test accuracy :",accuracy)
# Out:
# test loss : 0.23324495553970337
# test accuracy : 0.9294636249542236
